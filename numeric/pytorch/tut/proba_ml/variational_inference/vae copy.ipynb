# %%
# %load_ext autoreload
# %autoreload 2
import os
import random
from collections import OrderedDict, defaultdict
import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import ToTensor, Compose, Normalize
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

from mnist import MNIST, MNISTTrain, MNISTTest

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
batch_size = 1024 * 4

# %%
train_loader = DataLoader(dataset=MNISTTrain(transform=Compose([ToTensor(),])),
                          batch_size=batch_size, shuffle=True, num_workers=2)

# %%
test_loader = DataLoader(dataset=MNISTTest(transform=Compose([ToTensor(),])),
                          batch_size=batch_size, shuffle=False)

# %%
class Encoder(nn.Module):
    
    def __init__(self, hidden, zdim, dropout=0.1):
        super().__init__()
        self.fc1 = nn.Linear(784, hidden)
        self.std_net = nn.Linear(hidden, zdim)
        self.mu_net = nn.Linear(hidden, zdim)
        
            
    def forward(self, x):
        x = x.squeeze().view(-1, 784)
        feat1 = F.relu(self.fc1(x))
        mean = self.mu_net(feat1)
        std = torch.exp(self.std_net(feat1))
        return mean, std

class Decoder(nn.Module):
    
    def __init__(self, zdim, hidden, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(zdim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 784),
            )
    
    def forward(self, z):
        return self.net(z)


class VAE(nn.Module):
    
    def __init__(self, ):
        super().__init__()
        self.zdim = 50
        self.encoder = Encoder(hidden=400, zdim=self.zdim)
        self.decoder = Decoder(hidden=400, zdim=self.zdim,)
        
        self.apply(self.reset_parameters)
    
    def reset_parameters(self, module):
        if isinstance(module, nn.Linear):
            nn.init.xavier_normal_(module.weight, )
            if module.bias is not None:
                nn.init.constant_(module.bias, 0.)
            
    
    def forward(self, x):
        mean, std = self.encoder(x)
        # z = torch.normal(mean.clone().detach(), std.detach().clone())
        epsilon = mean.new_zeros(mean.size()).detach().copy_(torch.randn(mean.size()))
        z = mean + epsilon * std
        x_hat = self.decoder(z)
        return mean, std, z, x_hat

def log_normal_prob(x, mean, std, epsilon=1e-9):
    # Log normal for diagonal normal dist
    variance = std ** 2
    D = mean.size(-1)
    log_prob =  D * torch.log(torch.tensor(2*torch.pi)) + torch.log(variance + epsilon).sum(1) + ((x - mean).square() / (variance + epsilon)).sum(1)
    # print("Log prob: ",log_prob.size())
    return -0.5 * log_prob
    

class Criterion(nn.Module):
    
    def __init__(self, alpha_loss=1.0):
        super().__init__()
        self.alpha_loss = alpha_loss
        
        
    def forward(self, input, target, mean, std, z):
        reconstruction_loss = F.binary_cross_entropy_with_logits(input.view(input.size(0), -1), target.view(target.size(0), -1), reduction="none").sum(-1)
        zmean = mean.new_zeros(mean.size())
        zstd = mean.new_ones(mean.size())
        epsilon = mean.new_zeros(mean.size()).detach().copy_(torch.randn(mean.size()))
        
        log_p = -log_normal_prob(zmean + zstd * epsilon, zmean, zstd)
        log_q =  log_normal_prob(z, mean, std)
        loss = reconstruction_loss + log_p + log_q
        return loss.mean()

# %%
def train():
    model = VAE().cuda()
    criterion = Criterion()
    model.train()
    # optimizer = optim.Adam(model.parameters(), lr=3e-5)
    optimizer = optim.Adam(model.parameters(), lr=3e-5)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.98) 
    epochs = 100
    losses = []
    it = 0
    for i in range(epochs):
        print("Starting Epoch ", i, "...")
        for j, (img, label) in enumerate(train_loader):
            img = img.cuda()
            img /= 255.0
            mean, std, z, out = model(img)
            out = out.view(img.size())
            loss = criterion(out, img, mean, std, z)
            optimizer.zero_grad()
            loss.backward()
            it += 1
            nn.utils.clip_grad_norm_(model.parameters(), 1.)
            optimizer.step()
# Starting Epoch  73 ...
# Epoch: 73, batch: 42, loss: 63.79255767822266
# Starting Epoch  74 ...
# Epoch: 74, batch: 33, loss: 63.23609935760498
# Starting Epoch  75 ...
# Epoch: 75, batch: 24, loss: 62.658444519042966
# Starting Epoch  76 ...
# Epoch: 76, batch: 15, loss: 62.22889518737793
# Starting Epoch  77 ...
# Epoch: 77, batch: 6, loss: 61.74010498046875
# Epoch: 77, batch: 56, loss: 61.272269096374515
# Starting Epoch  78 ...
# Epoch: 78, batch: 47, loss: 60.84454257965088
# Starting Epoch  79 ...
# Epoch: 79, batch: 38, loss: 60.41124759674072
# Starting Epoch  80 ...
# Epoch: 80, batch: 29, loss: 59.99201179504394
# Starting Epoch  81 ...
# Epoch: 81, batch: 20, loss: 59.64251979827881
# Starting Epoch  82 ...
# Epoch: 82, batch: 11, loss: 59.219000282287595
# Starting Epoch  83 ...
# Epoch: 83, batch: 2, loss: 58.6505464553833
# Epoch: 83, batch: 52, loss: 58.315987815856936
# Starting Epoch  84 ...
# Epoch: 84, batch: 43, loss: 57.95139461517334
# Starting Epoch  85 ...
# Epoch: 85, batch: 34, loss: 57.53913799285888
# Starting Epoch  86 ...
# Epoch: 86, batch: 25, loss: 57.178689346313476
# Starting Epoch  87 ...
# Epoch: 87, batch: 16, loss: 56.88082012176514
# Starting Epoch  88 ...
# Epoch: 88, batch: 7, loss: 56.56005306243897
# Epoch: 88, batch: 57, loss: 56.04847297668457
# Starting Epoch  89 ...
# Epoch: 89, batch: 48, loss: 55.63732719421387
# Starting Epoch  90 ...
# Epoch: 90, batch: 39, loss: 55.34240005493164
# Starting Epoch  91 ...
# Epoch: 91, batch: 30, loss: 54.96216033935547
# Starting Epoch  92 ...
# Epoch: 92, batch: 21, loss: 54.692743072509764
# Starting Epoch  93 ...
# Epoch: 93, batch: 12, loss: 54.345495071411136
# Starting Epoch  94 ...
# Epoch: 94, batch: 3, loss: 54.04362407684326
# Epoch: 94, batch: 53, loss: 53.80571594238281
# Starting Epoch  95 ...
# Epoch: 95, batch: 44, loss: 53.483725776672365
# Starting Epoch  96 ...
# Epoch: 96, batch: 35, loss: 53.13844390869141
# Starting Epoch  97 ...
# Epoch: 97, batch: 26, loss: 52.74001152038574
# Starting Epoch  98 ...
# Epoch: 98, batch: 17, loss: 52.561079864501956
# Starting Epoch  99 ...
# Epoch: 99, batch: 8, loss: 52.23904991149902
# Epoch: 99, batch: 58, loss: 51.902040824890136

# %%
plt.plot(losses)

# %%
def plot_images(model, idx, nsamples=1000):
    with torch.no_grad():
        model.eval()
        img,label = test_loader.dataset[idx]
        img = img.unsqueeze(0).cuda()
        img /= 255.0
        mean, std, z, out = model(img.expand(nsamples, -1, -1, -1, -1))
        out = out.mean(axis=0)
        out = out.view(img.size())
        out = out[0].detach().cpu().permute(1, 2, 0)
        fig, (ax1, ax2) = plt.subplots(1, 2)
        ax1.imshow(img.squeeze(0).permute(1, 2, 0).detach().cpu())
        ax2.imshow(torch.sigmoid(out))
        fig.suptitle(label.item())

# %%
plot_images(model, 0)

# %%
plot_images(model, 2456, 500)

# %%
plot_images(model, 333, 2000)

# %%
for j in torch.randint(500, 2000, (10, )):
    plot_images(model, j, 2000)

# %%
for j in torch.randint(5000, 9999, (10,)):
    plot_images(model, j, 2000)

# %%
for j in torch.randint(5000, 9999, (10,)):
    plot_images(model, j, 2000)
