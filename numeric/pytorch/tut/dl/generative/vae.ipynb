# %%
# %load_ext autoreload
# %autoreload 2
import os
import random
from collections import OrderedDict, defaultdict
import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import ToTensor, Compose, Normalize
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

from mnist import MNIST, MNISTTrain, MNISTTest

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
batch_size = 1024 * 4

# %%
train_loader = DataLoader(dataset=MNISTTrain(transform=Compose([ToTensor(),])),
                          batch_size=batch_size, shuffle=True, num_workers=2)

# %%
test_loader = DataLoader(dataset=MNISTTest(transform=Compose([ToTensor(),])),
                          batch_size=batch_size, shuffle=False)

# %%
class Encoder(nn.Module):
    
    def __init__(self, hidden, zdim, dropout=0.1):
        super().__init__()
        self.fc1 = nn.Linear(784, hidden)
        self.std_net = nn.Linear(hidden, zdim)
        self.mu_net = nn.Linear(hidden, zdim)
        
            
    def forward(self, x):
        x = x.squeeze().view(-1, 784)
        feat1 = F.relu(self.fc1(x))
        mean = self.mu_net(feat1)
        std = torch.exp(self.std_net(feat1))
        return mean, std

class Decoder(nn.Module):
    
    def __init__(self, zdim, hidden, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(zdim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 784),
            )
    
    def forward(self, z):
        return self.net(z)


class VAE(nn.Module):
    
    def __init__(self, ):
        super().__init__()
        self.zdim = 50
        self.encoder = Encoder(hidden=400, zdim=self.zdim)
        self.decoder = Decoder(hidden=400, zdim=self.zdim,)
        
        self.apply(self.reset_parameters)
    
    def reset_parameters(self, module):
        if isinstance(module, nn.Linear):
            nn.init.xavier_normal_(module.weight, )
            if module.bias is not None:
                nn.init.constant_(module.bias, 0.)
            
    
    def forward(self, x):
        mean, std = self.encoder(x)
        # z = torch.normal(mean.clone().detach(), std.detach().clone())
        epsilon = mean.new_zeros(mean.size()).detach().copy_(torch.randn(mean.size()))
        z = mean + epsilon * std
        x_hat = self.decoder(z)
        return mean, std, z, x_hat

def log_normal_prob(x, mean, std, epsilon=1e-9):
    # Log normal for diagonal normal dist
    variance = std ** 2
    D = mean.size(-1)
    log_prob = -(D/2) * torch.log(torch.tensor(2*torch.pi)) - 0.5 * torch.log(variance + epsilon).sum(1) - 0.5 * ((x - mean).square() / (variance + epsilon)).sum(1)
    # print("Log prob: ",log_prob.size())
    return log_prob
    

class Criterion(nn.Module):
    
    def __init__(self, alpha_loss=1.0):
        super().__init__()
        self.alpha_loss = alpha_loss
        
        
    def forward(self, input, target, mean, std, z):
        reconstruction_loss = F.binary_cross_entropy_with_logits(input.view(input.size(0), -1), target.view(target.size(0), -1), reduction="none").sum(-1)
        assert mean.size(1) == 50
        # print(mean.size(), mean.dim)
        assert mean.dim() == 2
        kl_loss = 0.5 * (mean.square().sum(axis=1) + std.square().sum(axis=1) - mean.size(1) - 2 * torch.log(std).sum(axis=1))
        assert kl_loss.size() == torch.Size([mean.size(0)])
        assert reconstruction_loss.size() == torch.Size([mean.size(0)])
        loss = reconstruction_loss + self.alpha_loss * kl_loss
        # raise Exception
        return loss.mean()

# %%
def train():
    model = VAE().cuda()
    criterion = Criterion()
    model.train()
    # optimizer = optim.Adam(model.parameters(), lr=3e-5)
    optimizer = optim.Adam(model.parameters(), lr=3e-3)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.98) 
    epochs = 100
    losses = []
    it = 0
    for i in range(epochs):
        print("Starting Epoch ", i, "...")
        for j, (img, label) in enumerate(train_loader):
            img = img.cuda()
            img /= 255.0
            mean, std, z, out = model(img)
            out = out.view(img.size())
            loss = criterion(out, img, mean, std, z)
            optimizer.zero_grad()
            loss.backward()
            it += 1
            nn.utils.clip_grad_norm_(model.parameters(), 1.)
            optimizer.step()
            losses.append(loss.item())
            if it % 50 == 0:
                print(f"Epoch: {i}, batch: {j}, loss: {np.mean(losses[-100:])}")
        scheduler.step()

    return model, losses

# %%
model, losses = train()
# Out:
# Starting Epoch  0 ...
# Epoch: 0, batch: 49, loss: 264.5967074584961
# Starting Epoch  1 ...
# Epoch: 1, batch: 40, loss: 228.19908935546874
# Starting Epoch  2 ...
# Epoch: 2, batch: 31, loss: 184.86528717041017
# Starting Epoch  3 ...
# Epoch: 3, batch: 22, loss: 173.82528533935547
# Starting Epoch  4 ...
# Epoch: 4, batch: 13, loss: 167.08384918212892
# Starting Epoch  5 ...
# Epoch: 5, batch: 4, loss: 162.7065055847168
# Epoch: 5, batch: 54, loss: 159.56124908447265
# Starting Epoch  6 ...
# Epoch: 6, batch: 45, loss: 156.92891891479493
# Starting Epoch  7 ...
# Epoch: 7, batch: 36, loss: 154.80118850708007
# Starting Epoch  8 ...
# Epoch: 8, batch: 27, loss: 153.0916290283203
# Starting Epoch  9 ...
# Epoch: 9, batch: 18, loss: 151.59214630126954
# Starting Epoch  10 ...
# Epoch: 10, batch: 9, loss: 150.41888961791992
# Starting Epoch  11 ...
# Epoch: 11, batch: 0, loss: 149.7931802368164
# Epoch: 11, batch: 50, loss: 149.329871673584
# Starting Epoch  12 ...
# Epoch: 12, batch: 41, loss: 148.66538162231444
# Starting Epoch  13 ...
# Epoch: 13, batch: 32, loss: 148.09959899902344
# Starting Epoch  14 ...
# Epoch: 14, batch: 23, loss: 147.53763748168944
# Starting Epoch  15 ...
# Epoch: 15, batch: 14, loss: 147.00891845703126
# Starting Epoch  16 ...
# Epoch: 16, batch: 5, loss: 146.76840255737304
# Epoch: 16, batch: 55, loss: 146.48303192138673
# Starting Epoch  17 ...
# Epoch: 17, batch: 46, loss: 146.07574020385744
# Starting Epoch  18 ...
# Epoch: 18, batch: 37, loss: 145.7399836730957
# Starting Epoch  19 ...
# Epoch: 19, batch: 28, loss: 145.535408782959
# Starting Epoch  20 ...
# Epoch: 20, batch: 19, loss: 145.35614944458007
# Starting Epoch  21 ...
# Epoch: 21, batch: 10, loss: 145.09344482421875
# Starting Epoch  22 ...
# Epoch: 22, batch: 1, loss: 144.92960098266602
# Epoch: 22, batch: 51, loss: 144.76463455200195
# Starting Epoch  23 ...
# Epoch: 23, batch: 42, loss: 144.54439498901368
# Starting Epoch  24 ...
# Epoch: 24, batch: 33, loss: 144.28741607666015
# Starting Epoch  25 ...
# Epoch: 25, batch: 24, loss: 144.1002168273926
# Starting Epoch  26 ...
# Epoch: 26, batch: 15, loss: 144.02306579589845
# Starting Epoch  27 ...
# Epoch: 27, batch: 6, loss: 143.8818557739258
# Epoch: 27, batch: 56, loss: 143.72636291503906
# Starting Epoch  28 ...
# Epoch: 28, batch: 47, loss: 143.53531341552736
# Starting Epoch  29 ...
# Epoch: 29, batch: 38, loss: 143.41223861694337
# Starting Epoch  30 ...
# Epoch: 30, batch: 29, loss: 143.3965330505371
# Starting Epoch  31 ...
# Epoch: 31, batch: 20, loss: 143.24570999145507
# Starting Epoch  32 ...
# Epoch: 32, batch: 11, loss: 143.0777458190918
# Starting Epoch  33 ...
# Epoch: 33, batch: 2, loss: 143.09809616088867
# Epoch: 33, batch: 52, loss: 143.07059997558594
# Starting Epoch  34 ...
# Epoch: 72, batch: 1, loss: 140.5230043029785
# Epoch: 72, batch: 51, loss: 140.4989012145996
# Starting Epoch  73 ...
# Epoch: 73, batch: 42, loss: 140.46544357299805
# Starting Epoch  74 ...
# Epoch: 74, batch: 33, loss: 140.43733535766603
# Starting Epoch  75 ...
# Epoch: 75, batch: 24, loss: 140.37957443237303
# Starting Epoch  76 ...
# Epoch: 76, batch: 15, loss: 140.35743728637695
# Starting Epoch  77 ...
# Epoch: 77, batch: 6, loss: 140.3671028137207
# Epoch: 77, batch: 56, loss: 140.3128225708008
# Starting Epoch  78 ...
# Epoch: 78, batch: 47, loss: 140.28856216430665
# Starting Epoch  79 ...
# Epoch: 79, batch: 38, loss: 140.265869140625
# Starting Epoch  80 ...
# Epoch: 80, batch: 29, loss: 140.2370977783203
# Starting Epoch  81 ...
# Epoch: 81, batch: 20, loss: 140.17268325805665
# Starting Epoch  82 ...
# Epoch: 82, batch: 11, loss: 140.15501098632814
# Starting Epoch  83 ...
# Epoch: 83, batch: 2, loss: 140.1588101196289
# Epoch: 83, batch: 52, loss: 140.1254916381836
# Starting Epoch  84 ...
# Epoch: 84, batch: 43, loss: 140.13253723144533
# Starting Epoch  85 ...
# Epoch: 85, batch: 34, loss: 140.11907012939454
# Starting Epoch  86 ...
# Epoch: 86, batch: 25, loss: 140.07593383789063
# Starting Epoch  87 ...
# Epoch: 87, batch: 16, loss: 140.01035873413085
# Starting Epoch  88 ...
# Epoch: 88, batch: 7, loss: 139.98867446899413
# Epoch: 88, batch: 57, loss: 140.01278991699218
# Starting Epoch  89 ...
# Epoch: 89, batch: 48, loss: 139.98813232421875
# Starting Epoch  90 ...
# Epoch: 90, batch: 39, loss: 139.96328826904298
# Starting Epoch  91 ...
# Epoch: 91, batch: 30, loss: 139.92013214111327
# Starting Epoch  92 ...
# Epoch: 92, batch: 21, loss: 139.90632415771483
# Starting Epoch  93 ...
# Epoch: 93, batch: 12, loss: 139.94045013427734
# Starting Epoch  94 ...
# Epoch: 94, batch: 3, loss: 139.89800369262696
# Epoch: 94, batch: 53, loss: 139.86896865844727
# Starting Epoch  95 ...
# Epoch: 95, batch: 44, loss: 139.84643234252928
# Starting Epoch  96 ...
# Epoch: 96, batch: 35, loss: 139.83835388183593
# Starting Epoch  97 ...
# Epoch: 97, batch: 26, loss: 139.82555541992187
# Starting Epoch  98 ...
# Epoch: 98, batch: 17, loss: 139.8331913757324
# Starting Epoch  99 ...
# Epoch: 99, batch: 8, loss: 139.80402038574218
# Epoch: 99, batch: 58, loss: 139.76064758300782

# %%
plt.plot(losses)

# %%
def plot_images(model, idx, nsamples=1000):
    with torch.no_grad():
        model.eval()
        img,label = test_loader.dataset[idx]
        img = img.unsqueeze(0).cuda()
        img /= 255.0
        mean, std, z, out = model(img.expand(nsamples, -1, -1, -1, -1))
        out = out.mean(axis=0)
        out = out.view(img.size())
        out = out[0].detach().cpu().permute(1, 2, 0)
        fig, (ax1, ax2) = plt.subplots(1, 2)
        ax1.imshow(img.squeeze(0).permute(1, 2, 0).detach().cpu())
        ax2.imshow(torch.sigmoid(out))
        fig.suptitle(label.item())

# %%
plot_images(model, 0)

# %%
plot_images(model, 2456)

# %%
plot_images(model, 333, 1)

# %%
for j in torch.randint(5000, 9999, (10,)):
    plot_images(model, j, 2000)

# %%
for j in torch.randint(5000, 9999, (10,)):
    plot_images(model, j, 2000)
